# %% [markdown]
# <a href="https://colab.research.google.com/github/avejean21/Analytic-Modeling/blob/main/Mod_11_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ave Jean Zapata

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/mortgages.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
df = df.rename(columns={'Starting Balance': 'starting_balance',

'Interest Paid': 'interest_paid',

'Principal Paid': 'principal_paid'})
df.head()
# Out:
#    Month  starting_balance  Repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
df.columns = ['month',

'starting_balance',

'repayment',

'interest_paid',

'principal_paid',

'new_balance',

'mortgage_name',

'interest_rate']

df.head()
# Out:
#    month  starting_balance  repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    new_balance mortgage_name  interest_rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
f = df.drop(columns=['new_balance'])
df.head()
# Out:
#    month  starting_balance  repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    new_balance mortgage_name  interest_rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
del df['starting_balance']
df.head()
# Out:
#    month  repayment  interest_paid  principal_paid  new_balance mortgage_name  \
# 0      1    1686.42        1000.00          686.42    399313.58       30 Year
# 1      2    1686.42         998.28          688.14    398625.44       30 Year
# 2      3    1686.42         996.56          689.86    397935.58       30 Year
# 3      4    1686.42         994.83          691.59    397243.99       30 Year
# 4      5    1686.42         993.10          693.32    396550.67       30 Year
#
#    interest_rate
# 0           0.03
# 1           0.03
# 2           0.03
# 3           0.03
# 4           0.03
